# %%
import pandas as pd

join = pd.read_csv("jointure_4.csv")
join
# Out:
#            tconst titleType           primaryTitle  \
# 0       tt0094205     movie   Ubu and the Big Thug
# 1       tt0094205     movie   Ubu and the Big Thug
# 2       tt0094205     movie   Ubu and the Big Thug
# 3       tt0094205     movie   Ubu and the Big Thug
# 4       tt0094205     movie   Ubu and the Big Thug
# ...           ...       ...                    ...
# 536967  tt9778060     movie  A Matter of Causality
# 536968  tt9778060     movie  A Matter of Causality
# 536969  tt9861910     movie   The Story of a Panty
# 536970  tt9861910     movie   The Story of a Panty
# 536971  tt9861910     movie   The Story of a Panty
#
#                      originalTitle  isAdult  startYear endYear runtimeMinutes  \
# 0       Ubu et la grande Gidouille        0       1979      \N             80
# 1       Ubu et la grande Gidouille        0       1979      \N             80
# 2       Ubu et la grande Gidouille        0       1979      \N             80
# ...

# %%
join = join.drop(['isAdult', 'endYear', 'attributes', 'isOriginalTitle', 'birthYear', 'deathYear', 'region', 'language', 'types', 'titleType', 'job', 'characters', 'knownForTitles', 'averageRating', 'numVotes', 'ordering_y', 'title', 'runtimeMinutes'], axis=1)

# %%
join
# Out:
#            tconst           primaryTitle               originalTitle  \
# 0       tt0094205   Ubu and the Big Thug  Ubu et la grande Gidouille
# 1       tt0094205   Ubu and the Big Thug  Ubu et la grande Gidouille
# 2       tt0094205   Ubu and the Big Thug  Ubu et la grande Gidouille
# 3       tt0094205   Ubu and the Big Thug  Ubu et la grande Gidouille
# 4       tt0094205   Ubu and the Big Thug  Ubu et la grande Gidouille
# ...           ...                    ...                         ...
# 536967  tt9778060  A Matter of Causality       A Matter of Causality
# 536968  tt9778060  A Matter of Causality       A Matter of Causality
# 536969  tt9861910   The Story of a Panty        The Story of a Panty
# 536970  tt9861910   The Story of a Panty        The Story of a Panty
# 536971  tt9861910   The Story of a Panty        The Story of a Panty
#
#         startYear                 genres  ordering_x      nconst  \
# 0            1979  Animation,Crime,Drama           6   nm1770680
# ...

# %%
join.to_csv('jointure_4.csv')
